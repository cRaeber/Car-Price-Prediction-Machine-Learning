# %% [markdown]
# <a href="https://colab.research.google.com/github/cRaeber/Machine-Learning-Final-Project-Raeber-Chris/blob/main/CarDataAnalysis.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import seaborn as sns
sns.set(rc={'figure.figsize':(13,8.27)})

# %%
from google.colab import files
files.upload()

# %%
df = pd.read_csv('cars.csv')

# %%
df
# Out:
#              make         model transmission  color   miles  year      fuel  \
# 0            Audi            Q5    automatic  black   93270  2008  gasoline
# 1            Audi           100   mechanical  black  363100  1992    diesel
# 2            Audi            A6   mechanical  black     318  1997    diesel
# 3            Audi           100   mechanical  black  300000  1989  gasoline
# 4            Audi            Q5    automatic  black  157500  2013  gasoline
# ...           ...           ...          ...    ...     ...   ...       ...
# 17313  Volkswagen  T4 Caravelle   mechanical  white  380000  1994    diesel
# 17314  Volkswagen       Crafter   mechanical  white  212000  2012    diesel
# 17315  Volkswagen            LT   mechanical  white  542352  1993    diesel
# 17316  Volkswagen          Polo   mechanical  white       0  2019  gasoline
# 17317  Volkswagen       Crafter   mechanical  white  300000  2008    diesel
#
# ...

# %%
df.describe()
# Out:
#                 miles          year  engineCapacity         price  \
# count    15745.000000  15745.000000    15738.000000  15745.000000
# mean    250781.828009   2004.198222        2.220350   8228.702354
# std     131295.804561      7.232661        0.751419   6725.920971
# min          0.000000   1970.000000        0.200000   1100.000000
# 25%     160000.000000   1999.000000        1.800000   3500.000000
# 50%     246900.000000   2005.000000        2.000000   6500.000000
# 75%     325623.000000   2010.000000        2.500000  10700.000000
# max    1000000.000000   2019.000000        7.500000  50000.000000
#
#          timeListed
# count  15745.000000
# mean      82.366021
# std      110.381464
# min        0.000000
# 25%       25.000000
# 50%       61.000000
# 75%       92.000000
# max     2232.000000

# %%
sns.pairplot(df, hue='make')

# %%
sns.relplot(data=df, x='year', y='price', kind='line')

# %%
sns.scatterplot(data=df, x='miles', y='price', hue='make')

# %%
ax = sns.barplot(data=df, x='make', y='price')
ax.tick_params(axis='x', rotation=90)

# %%
ax = sns.barplot(data=df, x='year', y='price')
ax.tick_params(axis='x', rotation=90)

# %%
sns.relplot(data=df, x='engineCapacity', y='price', kind='line')

# %%
ax = sns.barplot(data=df, x='color', y='price')
ax.tick_params(axis='x', rotation=90)
